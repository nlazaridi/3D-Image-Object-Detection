# %%
'''
This notebooks contains code for visualizing several examples, mostly for the deliverable, reports etc

'''

# %%
import sys
import glob, os
import cv2
import numpy as np
sys.path.append("../")

from utils.utils import *

# %%
#read all images
save_path = "/home/andstasi/Projects/MediaVerse/3D_to_2D_converter/pytorch3d-renderer/results/Darbo/dist_1.1"
all_pngs = [os.path.join(save_path,f) for f in os.listdir(save_path) if f.endswith('.png')]

# %%
#initialize array
img = cv2.imread(all_pngs[0])
store_imgs = np.ones((len(all_pngs),img.shape[0],img.shape[1],img.shape[2]), dtype=np.uint32)
#append the array with alla images!
for i,png in enumerate(all_pngs):
    store_imgs[i] = cv2.cvtColor(cv2.imread(png), cv2.COLOR_BGR2RGB)

# %%
list_ind = [3,5,6,7,8,9,11,12,13,14,15,16,17,4,1]

# %%
image_grid(store_imgs[list_ind], save_path = os.path.join(save_path,"combined.png"),rows=3, cols=5)
